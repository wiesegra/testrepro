# %%
print((0.1+0.2)==0.3)

print((0.4+0.3)==0.7)
# Out:
# False
# True

# %%
print('''hello my name is



starwalker
''')

print('hello my name is



starwalker
')
# Out:
# hello my name is
#
#
#
# starwalker

# %%
8%2
# Out:
# 0

# %%
response = (input("What is my favorite color?"))
if str.upper(response) == "RED":
    print("FUCK YOU")
else:
    print("I LOVE YOU! " + response + " IS MY FAVORITE COLOR")
# Out:
# I LOVE YOU! asldc IS MY FAVORITE COLOR

# %%
msg = "hello"
print(type(msg))
msg = 1
print(type(msg))
# Out:
# <class 'str'>
# <class 'int'>

# %%
var1 = 10
var2 = var1
var3 = var2

var2 = 5

print(var3-1)
# Out:
# 9

# %%
abs(-2132)


def primer(x):
    if x <= 3 or x == 5:
        return "prime"
    elif x%2 == 1:
        if x%3 == 0 or x%5 == 0:
            return "not prime"
        else:
            return "prime"
    else:
        return "not prime"


for x in range(1,30):
    print(x, " is ", primer(x))
# Out:
# 1  is  prime
# 2  is  prime
# 3  is  prime
# 4  is  not prime
# 5  is  prime
# 6  is  not prime
# 7  is  prime
# 8  is  not prime
# 9  is  not prime
# 10  is  not prime
# 11  is  prime
# 12  is  not prime
# 13  is  prime
# 14  is  not prime
# 15  is  not prime
# 16  is  not prime
# 17  is  prime
# 18  is  not prime
# 19  is  prime
# 20  is  not prime
# 21  is  not prime
# 22  is  not prime
# 23  is  prime
# 24  is  not prime
# 25  is  not prime
# 26  is  not prime
# 27  is  not prime
# 28  is  not prime
# 29  is  prime

# %%
class BeeBoo:
    def __init__(self,i_favoritenumber,i_favoritecolor):
        self.x = i_favoritenumber
        self.y = i_favoritecolor
    def whatismyfavoritecolor(self):
        print(self.y)
    def ismyfavoritenumbereven(self):
        if self.x%2 == 0:
            print(self.x, "is even.")
        else:
            print(self.x, "is odd.")

class evilBeeBoo(BeeBoo):
    def __init__(self):
        self.x, self.y = super().x, super().y
    def whatismyfavoritecolor(self):
        print("you dont have a favorite color")
    def ismyfavoritenumbereven(self):
        if self.x%2 == 0:
            print(self.x, "is odd.")
        else:
            print(self.x, "is even.")
    

x = BeeBoo(11,"red")
x.ismyfavoritenumbereven()

x2 = evilBeeBoo(x)
x2.whatismyfavoritecolor()
# Out:
# 11 is odd.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 28
#      25 x = BeeBoo(11,"red")
#      26 x.ismyfavoritenumbereven()
# ---> 28 x2 = evilBeeBoo(x)
#      29 x2.whatismyfavoritecolor()
#
# TypeError: evilBeeBoo.__init__() takes 1 positional argument but 2 were given

# %%
coord = (1,0)

mymove = (3,12980374)

coord = (coord[0]+mymove[0], coord[1]+mymove[1])

print(coord)
# Out:
# (4, 12980374)

# %%
import random
class walker:
    def __init__(self):
        self.coord = [0,0]
    def step(self, x = None, y = None):
        if x == None or y == None:
            x = random.randint(-1,1)
            y = random.randint(-1,1)
            self.coord = [self.coord[0]+x, self.coord[1]+y]
        else:
            self.coord = [self.coord[0]+x, self.coord[1]+y]

        print(self.coord)
    def howfaraway(self, method = "Manhattan"):
        pass


helloworld = walker()
# Out:
# [0, 0]
# [0, -1]
# [-1, -1]
# [-1, -1]
# [0, -1]
# [1, -2]
# [0, -2]
# [1, -3]
# [2, -3]
# [1, -2]

# %%
print("I keep ballin so hard so so hard my guy")
